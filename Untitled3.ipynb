# %% [markdown]
# <a href="https://colab.research.google.com/github/rogstrixasus670-bot/cloud-computing/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_910/3305111549.py in <cell line: 0>()
# ----> 1 hello
#
# NameError: name 'hello' is not defined
